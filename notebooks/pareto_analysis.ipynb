# %% [markdown]
# # 4-D Pareto front inspection
#
# Scaffolded per docs/plan_R11.md §12.1. Notebook discipline (§12.2): keep this file under ~50 lines of orchestration only — all real logic lives in `src/fanopt/`.
#
# Reference: docs/plan_R11.md §6.4 + §Phase 4 step 51
